# %%
# Import necessary libraries
from tensorflow.keras.datasets import imdb
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
# Load the IMDB dataset
# Only keep the top 10,000 most frequently occurring words
(train_data, train_label), (test_data, test_label) = imdb.load_data(num_words=10000)

# %%
# Function to vectorize sequences (convert list of word indices into binary 10,000-dim vectors)
def vectorize_sequences(sequences, dimensions=10000):
    results = np.zeros((len(sequences), dimensions))
    for i, sequence in enumerate(sequences):
        results[i, sequence] = 1.0  # Set specific word positions to 1
    return results

# %%
# Prepare the input data
x_train = vectorize_sequences(train_data)  # Vectorize the training data
x_test = vectorize_sequences(test_data)    # Vectorize the test data

# %%
# Prepare the labels (ensure they are float32 for TensorFlow compatibility)
y_train = np.asarray(train_label).astype('float32')
y_test = np.asarray(test_label).astype('float32')

# %%
# Build the model
model = Sequential()
model.add(Dense(16, input_shape=(10000,), activation="relu"))  # First hidden layer
model.add(Dense(16, activation="relu"))                        # Second hidden layer
model.add(Dense(1, activation="sigmoid"))                      # Output layer (for binary classification)

# %%
# Compile the model
model.compile(optimizer='adam',
              loss='binary_crossentropy',  # Correct loss for binary classification
              metrics=['accuracy'])        # Track accuracy during training and evaluation

# %%
# Display model architecture
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_6 (Dense)                 │ (None, 16)             │       160,016 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 16)             │           272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 160,305 (626.19 KB)
#  Trainable params: 160,305 (626.19 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train the model
history = model.fit(
    x_train, y_train,
    validation_split=0.3,   # 30% of training data used for validation
    epochs=20,              # Train for 20 epochs
    batch_size=512,         # Use batches of 512 samples
    verbose=1               # Print progress bar
)
# Out:
# Epoch 1/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.6963 - loss: 0.6159 - val_accuracy: 0.8671 - val_loss: 0.3840
# Epoch 2/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.8973 - loss: 0.3186 - val_accuracy: 0.8867 - val_loss: 0.2919
# Epoch 3/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9299 - loss: 0.2163 - val_accuracy: 0.8901 - val_loss: 0.2756
# Epoch 4/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9463 - loss: 0.1692 - val_accuracy: 0.8903 - val_loss: 0.2736
# Epoch 5/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9560 - loss: 0.1392 - val_accuracy: 0.8867 - val_loss: 0.2851
# Epoch 6/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9698 - loss: 0.1065 - val_accuracy: 0.8833 - val_loss: 0.3076
# Epoch 7/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9769 - loss: 0.0851 - val_accuracy: 0.8803 - val_loss: 0.3295
# Epoch 8/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9842 - loss: 0.0700 - val_accuracy: 0.8784 - val_loss: 0.3578
# Epoch 9/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9893 - loss: 0.0547 - val_accuracy: 0.8776 - val_loss: 0.3892
# Epoch 10/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9925 - loss: 0.0432 - val_accuracy: 0.8736 - val_loss: 0.4226
# Epoch 11/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9948 - loss: 0.0356 - val_accuracy: 0.8741 - val_loss: 0.4556
# Epoch 12/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9969 - loss: 0.0286 - val_accuracy: 0.8720 - val_loss: 0.4880
# Epoch 13/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9980 - loss: 0.0209 - val_accuracy: 0.8697 - val_loss: 0.5249
# Epoch 14/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9989 - loss: 0.0185 - val_accuracy: 0.8691 - val_loss: 0.5527
# Epoch 15/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9993 - loss: 0.0139 - val_accuracy: 0.8669 - val_loss: 0.5828
# Epoch 16/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9994 - loss: 0.0112 - val_accuracy: 0.8668 - val_loss: 0.6120
# Epoch 17/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9996 - loss: 0.0092 - val_accuracy: 0.8656 - val_loss: 0.6388
# Epoch 18/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 1.0000 - loss: 0.0072 - val_accuracy: 0.8645 - val_loss: 0.6649
# Epoch 19/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 1.0000 - loss: 0.0060 - val_accuracy: 0.8632 - val_loss: 0.6887
# Epoch 20/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 1.0000 - loss: 0.0053 - val_accuracy: 0.8631 - val_loss: 0.7134

# %%
# Evaluate the model on test data
results = model.evaluate(x_test, y_test)
print(f"Test Loss: {results[0]:.4f}")
print(f"Test Accuracy: {results[1]*100:.2f}%")
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8530 - loss: 0.7674
# Test Loss: 0.7690
# Test Accuracy: 85.20%

# %%
# Print example prediction
print(f"First review predicted probability (positive): {predictions[0][0]:.4f}")
print("Predicted Sentiment:", "Positive" if predictions[0][0] > 0.5 else "Negative")
# Out:
# First review predicted probability (positive): 0.1429
# Predicted Sentiment: Negative
